# %% [markdown]
# * Project :: Analytic Titanic dataset

# %%
# Importing Liberares which we use on that Project
import numpy as np
import pandas as pd
import datasist as ds
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as w
w.filterwarnings("ignore")
# %matplotlib inline

# %%
# Loading dataset Which we Analytic it
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# * Present The first 10 samples of data

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# * Present The last 10 samples of data

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %% [markdown]
# * Present the info of The Features of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %% [markdown]
# * Present Statistical_description of data

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# * Identifing The Null values

# %%
Nulls = df.isnull().sum()
Nulls
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# * Identifing The NaN Values

# %%
NAN_Values = df.isna().sum()
NAN_Values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# * Present N_UNique data

# %%
Unique_data = df.nunique()
Unique_data
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %% [markdown]
# * Present Values Count of data

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
df["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df["who"].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
df["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
df["alone"].value_counts()
# Out:
# True     537
# False    354
# Name: alone, dtype: int64

# %% [markdown]
# * Using datasist Liberary To Present all data description ::
#     * Present ::
#         * 1_ The First Five Samples of data
#         * 2_ The Last Five Samples of data
#         * 3_ The Random Five Samples of data
#         * 4_ The Shape of data
#         * 5_ Numbers of samples and Columns
#         * 6_ dtypes of data
#         * 7_ Numerical_Features
#         * 8_Categorical_Features
#         * 9_Statistical_Analytics
#         * 10_Description of Categorical_Feartures
#         * 11_ Unique Classes of Categorical_Features
#         * 12_ Missing data Values

# %%
ds.structdata.describe(df)
# Out:
# First five data points
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# Random five data points
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 486         1       1  female  35.0      1      0  90.0000        S  First
# ...

# %% [markdown]
# * Viualization_dataset_Features ::
#      * Numerical_Features_Visualize
#        * Univariate
#        * Bivariate
#      * Categorical_Features_Visualize
#        * Univariate
#        * Bivariate

# %%
# SEt PLOTs Style
sns.set(rc = {"figure.figsize" : [10 , 10]} , font_scale=1.25)

# %% [markdown]
# * UniVariate_Numerical_Features ::
#   * ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'class', 'adult_male', 'deck', 'alone']

# %% [markdown]
# * That Numerical_data_values But haven't Mathimatical Meaning So that we Say its Categorical data

# %%
sns.distplot(df["survived"] , kde= False , bins=30 , color="m" )

# %%
sns.distplot(df["pclass"] , kde= False , bins=30 , color="m" )

# %%
sns.distplot(df["class"] , kde= False , bins=30 , color="m" )

# %%
sns.distplot(df["sibsp"] , kde= False , bins=30 , color="m" )

# %% [markdown]
# * Its Numerical data_values Which have Mathimatical_Meaning

# %%
sns.distplot(df["age"] , kde= False , bins=30 , color="m" )

# %%
* From The Result Of The Above Plot We See The The Most distribution of data in range of (20,30)

# %%
sns.distplot(df["fare"] , kde= False , bins=30 , color="m" )

# %%
sns.kdeplot(df["age"] , shade=True , color = "m")

# %%
sns.kdeplot(df["fare"] , shade=True , color = "m")

# %% [markdown]
# * That Plot above Help us to identify the Skweenss of data

# %% [markdown]
# * BiVariate Numerical_data_Plots

# %%
sns.jointplot( x = "age" , y = "fare" , kind= "scatter" , data = df , height=10)

# %%
sns.pairplot(df , vars=["age" , "fare" , "class"] , height=5 )

# %% [markdown]
# * Visualizeion using datasist Liberary

# %%
df.dropna(["deck","age"] , axis=1 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-70d1ccb8cbe2> in <module>
# ----> 1 df.dropna(["deck","age"] , axis=1 , inplace=True)
#
# TypeError: dropna() got multiple values for argument 'axis'

# %%
ds.visualizations.histogram(data = df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-7934cd4660fe> in <module>
# ----> 1 ds.visualizations.histogram(data = df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\datasist\visualizations.py in histogram(data, num_features, bins, show_dist_type, fig_size, save_fig)
#     290         ax = fig.gca()
#     291
# --> 292         sns.distplot(data[feature].values, ax=ax, bins=bins)
#     293         ax.set_xlabel(feature) # Set text for the x axis
#     294         ax.set_ylabel('Count')# Set text for y axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
# ...

# %% [markdown]
# * Visualization Categorical data  ::

# %% [markdown]
# * Bivariate plots

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# * Boxplot :: Used To identify there OutLiers or not

# %%
sns.boxenplot(x = "sex" , y = "age" , data = df , palette = "viridis")

# %%
sns.boxplot(x = "sex" , y = "age" , data = df , palette = "viridis")

# %%
sns.boxplot(x = "who" , y = "age" , data = df , palette = "viridis")

# %%
sns.boxplot(x = "sex" , y = "age" , data = df , hue= "who"  , palette = "viridis")

# %%
sns.boxplot(x = "alone" , y = "age" , data = df , hue= "who"  , palette = "viridis")

# %%
sns.boxplot(x = "alive" , y = "age" , data = df , hue= "who"  , palette = "viridis")

# %% [markdown]
# * Strip_Plots :: identifing The distribution of categorical_data

# %%
sns.stripplot(x = "sex" , y = "age" , data = df , palette = "viridis")

# %%
sns.stripplot(x = "sex" , y = "age" , data = df , hue= "who"  , palette = "viridis")

# %%
sns.stripplot(x = "sex" , y = "age" , data = df , hue= "who"  , dodge=True, palette = "viridis")

# %%
sns.stripplot(x='embark_town', y='age', data=df, hue='survived', dodge=True)

# %%
sns.swarmplot(x='embark_town', y='age', data=df, hue='survived', dodge=True)

# %% [markdown]
# * Bar Plot

# %%
sns.barplot(x='embark_town', y='age', data=df, hue='survived', dodge=True)

# %%
sns.barplot(x='embark_town', y='age', data=df, hue='survived', dodge=True , estimator=np.sum)

# %% [markdown]
# * Visualization UNivariate Categorical_data

# %%
sns.countplot( x = "age" , data = df , palette = "viridis" )

# %%
age_values = df["age"].value_counts()[:3]

# %%
sns.countplot(age_values , data = df , palette = "viridis")

# %%
fig = sns.countplot(age_values , data = df , palette = "viridis")
fig.set_xticklabels(labels = age_values.index , rotation =90)
# Out:
# [Text(0, 0, '24.0'),
#  Text(0, 0, '22.0'),
#  Text(0, 0, '18.0'),
#  Text(0, 0, '19.0'),
#  Text(0, 0, '30.0'),
#  Text(0, 0, '28.0'),
#  Text(0, 0, '21.0'),
#  Text(0, 0, '25.0'),
#  Text(0, 0, '36.0'),
#  Text(0, 0, '29.0'),
#  Text(0, 0, '32.0'),
#  Text(0, 0, '27.0'),
#  Text(0, 0, '35.0'),
#  Text(0, 0, '26.0'),
#  Text(0, 0, '16.0'),
#  Text(0, 0, '31.0'),
#  Text(0, 0, '20.0'),
#  Text(0, 0, '33.0'),
#  Text(0, 0, '23.0'),
#  Text(0, 0, '34.0')]

# %%
sns.countplot(df["sex"] , data = df , palette = "viridis")

# %%
sns.countplot(df["sex"] , data = df ,hue="who" , palette = "viridis")

# %%
sns.countplot(df["sex"] , data = df ,hue="class" , palette = "viridis")

# %%
sns.countplot(df["class"] , data = df ,hue="who" , palette = "viridis")

# %% [markdown]
# * Visualization Using datasist Liberary

# %%
ds.visualizations.boxplot(df , target="sex")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-493356feee45> in <module>
# ----> 1 ds.visualizations.boxplot(df , target="sex")
#
# C:\ProgramData\Anaconda3\lib\site-packages\datasist\visualizations.py in boxplot(data, num_features, target, fig_size, large_data, save_fig)
#     167
#     168             sns.set_style("whitegrid")
# --> 169             sns.boxplot(target, feature, data=data, ax=ax)
#     170             plt.ylabel(feature) # Set text for the x axis
#     171             plt.xlabel(target)# Set text for y axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
# ...

# %%
ds.visualizations.countplot(df )

# %%
ds.visualizations.plot_missing(df )

# %%
ds.visualizations.scatterplot(df , target="age")

# %%
ds.visualizations.catbox(data = df ,target="sex")

# %% [markdown]
# * Visualization Matrix

# %%
sns.heatmap(df.corr() , annot=True)

# %%
sns.heatmap(df.corr() , annot=True , cmap="viridis")

# %% [markdown]
# * Craeting Pivot Tabels

# %%
P_Table = pd.pivot_table(columns="pclass" , values="fare" , index="age" , data =df)

# %%
P_Table
# Out:
# pclass         1       2        3
# age
# 0.42         NaN     NaN   8.5167
# 0.67         NaN  14.500      NaN
# 0.75         NaN     NaN  19.2583
# 0.83         NaN  23.875      NaN
# 0.92    151.5500     NaN      NaN
# ...          ...     ...      ...
# 70.00    71.0000  10.500      NaN
# 70.50        NaN     NaN   7.7500
# 71.00    42.0792     NaN      NaN
# 74.00        NaN     NaN   7.7750
# 80.00    30.0000     NaN      NaN
#
# [88 rows x 3 columns]

# %%
P_Table.fillna(value=20)
# Out:
# pclass         1       2        3
# age
# 0.42     20.0000  20.000   8.5167
# 0.67     20.0000  14.500  20.0000
# 0.75     20.0000  20.000  19.2583
# 0.83     20.0000  23.875  20.0000
# 0.92    151.5500  20.000  20.0000
# ...          ...     ...      ...
# 70.00    71.0000  10.500  20.0000
# 70.50    20.0000  20.000   7.7500
# 71.00    42.0792  20.000  20.0000
# 74.00    20.0000  20.000   7.7750
# 80.00    30.0000  20.000  20.0000
#
# [88 rows x 3 columns]

# %%
sns.heatmap(P_Table.corr() , annot=True)
