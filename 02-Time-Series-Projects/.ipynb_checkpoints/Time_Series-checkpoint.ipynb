# %%
import numpy     as np
import pandas    as pd
import seaborn   as sns
import missingno as mno
import warnings  as w
import pandas_profiling  as pp
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
w.filterwarnings("ignore")
sns.set(rc = {"figure.figsize" : [20 , 10]} , font_scale = 1.7)

# %%
df = pd.read_csv("opsd_germany_daily.csv")
df
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df.head(10)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN
# 5  2006-01-06     1403.427   NaN    NaN         NaN
# 6  2006-01-07     1300.287   NaN    NaN         NaN
# 7  2006-01-08     1207.985   NaN    NaN         NaN
# 8  2006-01-09     1529.323   NaN    NaN         NaN
# 9  2006-01-10     1576.911   NaN    NaN         NaN

# %%
df.tail(10)
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4373  2017-12-22   1423.23782  228.773  10.065     238.838
# 4374  2017-12-23   1272.17085  748.074   8.450     756.524
# 4375  2017-12-24   1141.75730  812.422   9.949     822.371
# 4376  2017-12-25   1111.28338  587.810  15.765     603.575
# 4377  2017-12-26   1130.11683  717.453  30.923     748.376
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df.sample(10 , random_state=20)
# Out:
#             Date  Consumption     Wind    Solar  Wind+Solar
# 3607  2015-11-17     1542.282  493.618   15.270     508.888
# 2708  2013-06-01     1031.124  232.191   51.370     283.561
# 3626  2015-12-06     1232.073  589.627   39.065     628.692
# 4167  2017-05-30     1450.411  212.497  166.431     378.928
# 1679  2010-08-07     1073.063   42.859      NaN         NaN
# 1632  2010-06-21     1310.216   32.632      NaN         NaN
# 2759  2013-07-22     1280.555   24.172  197.601     221.773
# 1435  2009-12-06     1156.702      NaN      NaN         NaN
# 2388  2012-07-16     1244.002  167.532  116.698     284.230
# 2633  2013-03-18     1336.399  217.252   41.638     258.890

# %%
df.dtypes
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Consumption', 'Wind', 'Solar', 'Wind+Solar'], dtype='object')

# %%
df.describe(include = "number")
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  2920.000000  2188.000000  2187.000000
# mean   1338.675836   164.814173    89.258695   272.663481
# std     165.775710   143.692732    58.550099   146.319884
# min     842.395000     5.757000     1.968000    21.478000
# 25%    1217.859000    62.353250    35.179250   172.185500
# 50%    1367.123000   119.098000    86.407000   240.991000
# 75%    1457.761000   217.900250   135.071500   338.988000
# max    1709.568000   826.278000   241.580000   851.556000

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# %%
df
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Week_Day'] = df['Date'].dt.weekday

# %%
df[["Year" , "Month" , "Week_Day"]]
# Out:
#       Year  Month  Week_Day
# 0     2006      1         6
# 1     2006      1         0
# 2     2006      1         1
# 3     2006      1         2
# 4     2006      1         3
# ...    ...    ...       ...
# 4378  2017     12         2
# 4379  2017     12         3
# 4380  2017     12         4
# 4381  2017     12         5
# 4382  2017     12         6
#
# [4383 rows x 3 columns]

# %%
df.set_index("Date" , inplace=True)

# %%
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Week_Day
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1         6
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1         0
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1         1
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1         2
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1         3
# ...                 ...      ...     ...         ...   ...    ...       ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12         2
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12         3
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12         4
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12         5
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12         6
#
# [4383 rows x 7 columns]

# %%
df["Consumption"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Wind"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Solar"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Wind+Solar"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Consumption"].plot()
df["Solar"].plot()
df["Wind"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cols = ["Consumption" , "Solar" , "Wind"]
axes =df[ cols].plot(subplots = True)

# %%
df.loc["2017" , "Consumption"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.loc["2017" , "Consumption"].plot(marker = "o")
plt.ylabel("Daily Consumption")
# Out:
# Text(0, 0.5, 'Daily Consumption')

# %%
df.loc["2017-01" : "2017-02" , "Consumption"].plot(marker = "o")
plt.ylabel("Daily Consumption")
# Out:
# Text(0, 0.5, 'Daily Consumption')

# %%
 df
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Week_Day
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1         6
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1         0
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1         1
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1         2
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1         3
# ...                 ...      ...     ...         ...   ...    ...       ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12         2
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12         3
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12         4
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12         5
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12         6
#
# [4383 rows x 7 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar  Year  Month  \
# 0    2006-01-01   1069.18400      NaN     NaN         NaN  2006      1
# 1    2006-01-02   1380.52100      NaN     NaN         NaN  2006      1
# 2    2006-01-03   1442.53300      NaN     NaN         NaN  2006      1
# 3    2006-01-04   1457.21700      NaN     NaN         NaN  2006      1
# 4    2006-01-05   1477.13100      NaN     NaN         NaN  2006      1
# ...         ...          ...      ...     ...         ...   ...    ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12
#
#       Week_Day
# 0            6
# 1            0
# 2            1
# 3            2
# 4            3
# ...        ...
# 4378         2
# 4379         3
# 4380         4
# 4381         5
# 4382         6
#
# [4383 rows x 8 columns]

# %%
y_true = df["Date"]

# %%
from statsmodels.tsa.ar_model import AR 
from statsmodels.tsa.arima_model import ARMA  
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
df = pd.read_csv("multiTimeline.csv", skiprows=1)
df
# Out:
#        Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0    2004-01                100                31                    48
# 1    2004-02                 75                26                    49
# 2    2004-03                 67                24                    47
# 3    2004-04                 70                22                    48
# 4    2004-05                 72                22                    43
# ..       ...                ...               ...                   ...
# 163  2017-08                 46                52                    43
# 164  2017-09                 44                50                    47
# 165  2017-10                 44                47                    45
# 166  2017-11                 41                47                    47
# 167  2017-12                 39                45                    56
#
# [168 rows x 4 columns]

# %%
df.columns = ["month" , "diet" , "gym" , "finance"]

# %%
df
# Out:
#        month  diet  gym  finance
# 0    2004-01   100   31       48
# 1    2004-02    75   26       49
# 2    2004-03    67   24       47
# 3    2004-04    70   22       48
# 4    2004-05    72   22       43
# ..       ...   ...  ...      ...
# 163  2017-08    46   52       43
# 164  2017-09    44   50       47
# 165  2017-10    44   47       45
# 166  2017-11    41   47       47
# 167  2017-12    39   45       56
#
# [168 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    168 non-null    object
#  1   diet     168 non-null    int64
#  2   gym      168 non-null    int64
#  3   finance  168 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.4+ KB

# %%
df["month"] = pd.to_datetime(df["month"])

# %%
df.set_index("month" , inplace=True)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
cols = ["diet" , "gym" , "finance"]
df[cols].plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='month'>, <AxesSubplot:xlabel='month'>,
#        <AxesSubplot:xlabel='month'>], dtype=object)

# %%
diet , gym , finance = df[["diet"]] , df[["gym"]] , df[["finance"]]

# %%
diet.plot()
plt.title("diet without rolling")
diet.rolling(12).sum().plot()
plt.title("diet with sum rolling")
diet.rolling(12).mean().plot()
plt.title("diet with mean rolling")
# Out:
# Text(0.5, 1.0, 'diet with mean rolling')

# %%
gym.plot()
plt.title("gym without rolling")
gym.rolling(12).sum().plot()
plt.title("gym with sum rolling")
gym.rolling(12).mean().plot()
plt.title("gym with mean rolling")
# Out:
# Text(0.5, 1.0, 'gym with mean rolling')

# %%
finance.plot()
plt.title("finance without rolling")
finance.rolling(12).sum().plot()
plt.title("finance with sum rolling")
finance.rolling(12).mean().plot()
plt.title("finance with mean rolling")
# Out:
# Text(0.5, 1.0, 'finance with mean rolling')

# %%
diet_gym_finance = pd.concat([diet.rolling(12).mean() , gym.rolling(12).mean() , finance.rolling(12).mean()] , axis= 1)

# %%
diet_gym_finance.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
diet.diff().plot()
plt.title("diff of diet")
gym.diff().plot()
plt.title("gym of diet")
finance.diff().plot()
plt.title("finance of diet")
# Out:
# Text(0.5, 1.0, 'finance of diet')

# %%
df.corr()
# Out:
#              diet       gym   finance
# diet     1.000000 -0.100764 -0.034639
# gym     -0.100764  1.000000 -0.284279
# finance -0.034639 -0.284279  1.000000

# %%
df.diff().corr()
# Out:
#              diet       gym   finance
# diet     1.000000  0.758707  0.373828
# gym      0.758707  1.000000  0.301111
# finance  0.373828  0.301111  1.000000

# %%
df.diff().plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
pd.plotting.autocorrelation_plot(diet)
pd.plotting.autocorrelation_plot(gym)
pd.plotting.autocorrelation_plot(finance)
plt.title("Autocoreelation of all features")
# Out:
# Text(0.5, 1.0, 'Autocoreelation of all features')

# %%
pd.plotting.autocorrelation_plot(diet)
plt.title("Autocoreelation of diet")
# Out:
# Text(0.5, 1.0, 'Autocoreelation of diet')

# %%
pd.plotting.autocorrelation_plot(gym)
plt.title("Autocoreelation of gym")
# Out:
# Text(0.5, 1.0, 'Autocoreelation of gym')

# %%
pd.plotting.autocorrelation_plot(finance)
plt.title("Autocoreelation of finance")
# Out:
# Text(0.5, 1.0, 'Autocoreelation of finance')
