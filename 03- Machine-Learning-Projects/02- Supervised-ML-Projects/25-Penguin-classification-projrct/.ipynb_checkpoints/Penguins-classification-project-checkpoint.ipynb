# %% [markdown]
# # - The project :: Penguin Classification Project
# *****************************************************************
# <img src="images/penguin.jpeg" />
#
#
# # overview about How ML Solve That Problem? :
# **********************************
# <img src="images/Tel1.png" />

# %% [markdown]
# * Table of Contetnt ::
# ************************************************
# <ul>
# <li><a href="#Intro">Introduction</a></li>
# <li><a href="#Wrangling">Exploratory Data Analysis (EDA)</a></li>
# <li><a href="#visualize">Data_Visualization_Process</a></li>
# <li><a href="#ETl">ETl_Process</a></li>
# <li><a href="#Prepration">Data_Prepration</a></li>
# <li><a href="#Model">Bulid_ML_Model</a></li>
# <li><a href="#Evaluation">Evaluate_Model</a></li>
# <li><a href="#Save">Save_Model</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# * Describtion of project ::
#     *************************
#     * Business ::
#          * Any Business Want To Maximize The Numbers of CLients.
#          * That Not Based on Attract New ones Only But Bases also on Retaining the Existing ones.
#          * The Current or old Clients Will Cost the Company Less Than The New_Clients
#          * The New_Clients Weekly interested in Business Servicies and They consider difficult to work with it But The Retain Clients have the necessary knowldge and info Towardes the Business services.
# <img src="images/Tel2.png" />
#
#     * Domain_Knowledge ::
#          * That Project disscuss one of the Most common problem that cosider the telecom cooperate, which Clients Churn, also define as Clients retention or Clients Turnover, is that loss clients or save them.
#          * Telephone service companies, Internet service providers, pay-TV companies, insurance firms, and alarm monitoring services, often use Clients attrition analysis and customer attrition rates as one of their key business metrics because the cost of retaining an existing customer is far less than acquiring a new one. Companies from these sectors often have customer service branches that attempt to win back defecting clients, because recovered long-term Clients can be worth much more to a company than newly recruited clients.
#          * Companies usually make a distinction between voluntary churn and involuntary churn. Voluntary churn occurs due to a decision by the Client to switch to another company or service provider, involuntary churn occurs due to circumstances such as a Client's relocation to a long-term care facility, death, or the relocation to a distant location. In most applications, involuntary reasons for churn are excluded from the analytical models. Analysts tend to concentrate on voluntary churn, because it typically occurs due to factors of the Company-Clients relationship which companies control, such as how billing interactions are handled or how after-sales help is provided.
#          * predictive analytics use churn prediction models that predict customer churn by assessing their propensity of risk to churn. Since these models generate a small prioritized list of potential defectors, they are effective at focusing customer retention marketing programs on the subset of the Clients base who are most vulnerable to churn.
# <img src="images/Tel3.png" />
#
#     * Data ::
#          * We Have data belongings to Tellecom Services Which Present The Behaviour of the Clients with The Business Services
#          * We Have dataset from a telecommunications company. The data contains information about almost six thousand users, their demographic characteristics, the services they use, the duration of using the operator's services, the method of payment, and the amount of payment.
#          * We Must Known That  Task of Attract New_Clients More difficulte and need more efforts Than thae task of Keep the old Clients Use Our Business Servicies.
#     * Tasks ::
#         * *Apply EDA Technice To* :: Describe The Behavior of the data For Extractng Meaningfull Knowledge , insights and Vision From That data To Make The Steckholders of our Business Make More Efficient Decision Which improve and develop The Business
#         * Research Of dependences and Formulation of Hypothess.
#         * Built ML Model For Predciting New_Values Of Churn.
#         * Get High Accuracy From the Model Performance To improve Our Business .
#
# <img src="images/Process.png" />

# %% [markdown]
# * Importing requried liberaries and Frameworks  ::

# %%
# Importing Liberaries and Framworks ::
import numpy     as np      # Apply Linear_Algebra operations and deal with arrays.
import pandas    as pd      # For Loading diff formats of data and Apply Wrangling and Mainpulating on data
import seaborn   as sns     # For Visualizing data
import warnings  as w       # For Ignoring any Warning
import missingno as mno     # Presnt Precentage of Nan Values
import datasist  as ds      # For Apply EDA and Visualization Using Simple Implementation
import matplotlib.pyplot as plt # For Set Plots , Charts and Maps Labels and Title  
import pandas_profiling  as pp  # To get describtion file of data

# %% [markdown]
# * Set some instructions

# %%
# To Make Matplotlib apply on any Version
# %matplotlib inline      
# To ignore any Warning notification.
w.filterwarnings("ignore") 
# To Set Figsize of Plots , Charts and Maps
sns.set( rc = {"figure.figsize" : [50 , 35]} , font_scale=3.5)

# %%
# Loading dataset ::
df = pd.read_csv("penguins_size.csv")
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# <p id="Wrangling">Exploratory data analysis</p>

# %% [markdown]
# * *EDA Task* ::
# *******************************
#  *  It one of the most important phase of data scientist life cycle which we apply some statistical oprations toidentify the Behaviour of data  to extract meaningful knowledge , insights and vesion from that data to help steckholders to make more efficient decision which improve and enhance our Buesines.

# %% [markdown]
# * Statistical analysis Process ::

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# Investigate Data not include null values ::
# Let's take a look at the presence of missing values, so as not to face unpleasant surprises in the future.


mno.bar(df)
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# identify the unique data values and its values count ::
for col in df.columns :
    print(f"The Col :: ({col})\n\nThe Col _ ({col}) _Unique_values :: {df[col].unique()}\n\n\
The Col _ ({col})_Value_counts :: \n\n{df[col].value_counts()}\n\n-----------\n-----------\n")
# Out:
# The Col :: (species)
#
# The Col _ (species) _Unique_values :: ['Adelie' 'Chinstrap' 'Gentoo']
#
# The Col _ (species)_Value_counts ::
#
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64
#
# -----------
# -----------
#
# The Col :: (island)
#
# The Col _ (island) _Unique_values :: ['Torgersen' 'Biscoe' 'Dream']
#
# The Col _ (island)_Value_counts ::
#
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64
#
# -----------
# -----------
#
# The Col :: (culmen_length_mm)
#
# The Col _ (culmen_length_mm) _Unique_values :: [39.1 39.5 40.3  nan 36.7 39.3 38.9 39.2 34.1 42.  37.8 41.1 38.6 34.6
#  36.6 38.7 42.5 34.4 46.  37.7 35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2
#  40.9 36.4 42.2 37.6 39.8 36.5 40.8 36.  44.1 37.  39.6 37.5 42.3 40.1
#  35.  34.5 41.4 39.  35.7 41.3 41.6 35.5 41.8 33.5 39.7 45.8 42.8 36.2
#  42.1 42.9 35.1 37.3 36.3 36.9 38.3 34.  38.1 33.1 43.2 41.  45.6 42.7
# ...

# %%
# Present the Statistical Analysis describtion of Numerical_data ::
df.describe(include=["number"])
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
# present the Statistical Analysis description of Categorical_data ::
df.describe(include="object")
# Out:
#        species  island   sex
# count      344     344   334
# unique       3       3     3
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %%
# Present nuniques :: To identifing the duplicaties data
df.nunique()
# Out:
# species                3
# island                 3
# culmen_length_mm     164
# culmen_depth_mm       80
# flipper_length_mm     55
# body_mass_g           94
# sex                    3
# dtype: int64

# %%
# check data include duplicates record or not
df.duplicated().sum()
# Out:
# 0

# %%
# Droping All repeat or Redendant data.
df.drop_duplicates(inplace=True)

# %%
# Checking dtypes of dataset.
df.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# * Wrangling and Mainplluting data.

# %%
# Get The Record Of the Clients who max culmen_length_mm ::
df[df["culmen_length_mm"] == df["culmen_length_mm"].max()]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 253  Gentoo  Biscoe              59.6             17.0              230.0
#
#      body_mass_g   sex
# 253       6050.0  MALE

# %%
# Get The Record of the Min culmen_length_mm ::
df[df["culmen_length_mm"] == df["culmen_length_mm"].min()]
# Out:
#     species island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 142  Adelie  Dream              32.1             15.5              188.0
#
#      body_mass_g     sex
# 142       3050.0  FEMALE

# %%
# Get The Record Of the Clients who max culmen_depth_mm ::
df[df["culmen_depth_mm"] == df["culmen_depth_mm"].max()]
# Out:
#    species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 19  Adelie  Torgersen              46.0             21.5              194.0
#
#     body_mass_g   sex
# 19       4200.0  MALE

# %%
# Get The Record of the Min culmen_depth_mm ::
df[df["culmen_depth_mm"] == df["culmen_depth_mm"].min()]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 244  Gentoo  Biscoe              42.9             13.1              215.0
#
#      body_mass_g     sex
# 244       5000.0  FEMALE

# %%
# Get The Record Of the Clients who max flipper_length_mm ::
df[df["flipper_length_mm"] == df["flipper_length_mm"].max()]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 283  Gentoo  Biscoe              54.3             15.7              231.0
#
#      body_mass_g   sex
# 283       5650.0  MALE

# %%
# Get The Record of the Min flipper_length_mm ::
df[df["flipper_length_mm"] == df["flipper_length_mm"].min()]
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 28  Adelie  Biscoe              37.9             18.6              172.0
#
#     body_mass_g     sex
# 28       3150.0  FEMALE

# %%
# Get The Record Of the Clients who max body_mass_g ::
df[df["body_mass_g"] == df["body_mass_g"].max()]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 237  Gentoo  Biscoe              49.2             15.2              221.0
#
#      body_mass_g   sex
# 237       6300.0  MALE

# %%
# Get The Record of the Min body_mass_g ::
df[df["body_mass_g"] == df["body_mass_g"].min()]
# Out:
#        species island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 190  Chinstrap  Dream              46.9             16.6              192.0
#
#      body_mass_g     sex
# 190       2700.0  FEMALE

# %%
df.head(2)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
# grouped data ased on species feature and get col describtion ::
df.groupby("species").describe().transpose()
# Out:
# species                       Adelie    Chinstrap       Gentoo
# culmen_length_mm  count   151.000000    68.000000   123.000000
#                   mean     38.791391    48.833824    47.504878
#                   std       2.663405     3.339256     3.081857
#                   min      32.100000    40.900000    40.900000
#                   25%      36.750000    46.350000    45.300000
#                   50%      38.800000    49.550000    47.300000
#                   75%      40.750000    51.075000    49.550000
#                   max      46.000000    58.000000    59.600000
# culmen_depth_mm   count   151.000000    68.000000   123.000000
#                   mean     18.346358    18.420588    14.982114
#                   std       1.216650     1.135395     0.981220
#                   min      15.500000    16.400000    13.100000
#                   25%      17.500000    17.500000    14.200000
#                   50%      18.400000    18.450000    15.000000
# ...

# %%
# grouped data ased on island feature and get col describtion ::
df.groupby("island").describe().transpose()
# Out:
# island                        Biscoe        Dream    Torgersen
# culmen_length_mm  count   167.000000   124.000000    51.000000
#                   mean     45.257485    44.167742    38.950980
#                   std       4.772731     5.953527     3.025318
#                   min      34.500000    32.100000    33.500000
#                   25%      42.000000    39.150000    36.650000
#                   50%      45.800000    44.650000    38.900000
#                   75%      48.700000    49.850000    41.100000
#                   max      59.600000    58.000000    46.000000
# culmen_depth_mm   count   167.000000   124.000000    51.000000
#                   mean     15.874850    18.344355    18.429412
#                   std       1.820721     1.133116     1.339447
#                   min      13.100000    15.500000    15.900000
#                   25%      14.500000    17.500000    17.350000
#                   50%      15.500000    18.400000    18.400000
# ...

# %%
# grouped data ased on sex feature and get col describtion ::
df.groupby("sex").describe().transpose()
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0   165.000000   168.000000
#                   mean     44.5    42.096970    45.854762
#                   std       NaN     4.903476     5.366896
#                   min      44.5    32.100000    34.600000
#                   25%      44.5    37.600000    40.975000
#                   50%      44.5    42.800000    46.800000
#                   75%      44.5    46.200000    50.325000
#                   max      44.5    58.000000    59.600000
# culmen_depth_mm   count     1.0   165.000000   168.000000
#                   mean     15.7    16.425455    17.891071
#                   std       NaN     1.795681     1.863351
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    14.500000    16.075000
#                   50%      15.7    17.000000    18.450000
#                   75%      15.7    17.800000    19.250000
# ...

# %%
df.head(2)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
Pivot_T1 = pd.pivot_table(df , index = "species" , columns = "sex" , values = "culmen_length_mm")
Pivot_T1
# Out:
# sex           .     FEMALE       MALE
# species
# Adelie      NaN  37.257534  40.390411
# Chinstrap   NaN  46.573529  51.094118
# Gentoo     44.5  45.563793  49.473770

# %%
Pivot_T2 = pd.pivot_table(df , index = "species" , columns = "sex" , values = "culmen_depth_mm")
Pivot_T2
# Out:
# sex           .     FEMALE       MALE
# species
# Adelie      NaN  17.621918  19.072603
# Chinstrap   NaN  17.588235  19.252941
# Gentoo     15.7  14.237931  15.718033

# %%
Pivot_T3 = pd.pivot_table(df , index = "species" , columns = "sex" , values = "flipper_length_mm")
Pivot_T3
# Out:
# sex            .      FEMALE        MALE
# species
# Adelie       NaN  187.794521  192.410959
# Chinstrap    NaN  191.735294  199.911765
# Gentoo     217.0  212.706897  221.540984

# %%
Pivot_T4 = pd.pivot_table(df , index = "species" , columns = "sex" , values = "body_mass_g")
Pivot_T4
# Out:
# sex             .       FEMALE         MALE
# species
# Adelie        NaN  3368.835616  4043.493151
# Chinstrap     NaN  3527.205882  3938.970588
# Gentoo     4875.0  4679.741379  5484.836066

# %%
Pivot_T1 = pd.pivot_table(df , index = "island" , columns = "sex" , values = "culmen_length_mm")
Pivot_T1
# Out:
# sex           .     FEMALE       MALE
# island
# Biscoe     44.5  43.307500  47.119277
# Dream       NaN  42.296721  46.116129
# Torgersen   NaN  37.554167  40.586957

# %%
Pivot_T2 = pd.pivot_table(df , index = "island" , columns = "sex" , values = "culmen_depth_mm")
Pivot_T2
# Out:
# sex           .     FEMALE       MALE
# island
# Biscoe     15.7  15.191250  16.597590
# Dream       NaN  17.601639  19.066129
# Torgersen   NaN  17.550000  19.391304

# %%
Pivot_T3 = pd.pivot_table(df , index = "island" , columns = "sex" , values = "flipper_length_mm")
Pivot_T3
# Out:
# sex            .      FEMALE        MALE
# island
# Biscoe     217.0  205.687500  213.289157
# Dream        NaN  190.016393  196.306452
# Torgersen    NaN  188.291667  194.913043

# %%
Pivot_T4 = pd.pivot_table(df , index = "island" , columns = "sex" , values = "body_mass_g")
Pivot_T4
# Out:
# sex             .       FEMALE         MALE
# island
# Biscoe     4875.0  4319.375000  5104.518072
# Dream         NaN  3446.311475  3987.096774
# Torgersen     NaN  3395.833333  4034.782609

# %%
Con_Matrix = df.corr()
Con_Matrix
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# <p id="visualize"> Visualization-Process</p>

# %% [markdown]
# * Apply Data-Visualization Process ::
# *******************************************
# * visualization data one of the most important process on data scientist life cycle which we use some viualize element such (charts , plots ,maps) to identify the pattern , Trends and outliers on data.

# %%
# Visualize The Feathure Correlations ::
sns.set( rc = {"figure.figsize" : [10 , 10]} , font_scale=1.5)
sns.heatmap(Con_Matrix , annot=True , cmap="YlGnBu" , linecolor="r" , linewidths=0.5)
plt.xticks(rotation = 30)
plt.yticks(rotation = 30)
plt.title("Confusion_Matrix of data")
# RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r
# Out:
# Text(0.5, 1.0, 'Confusion_Matrix of data')

# %%
df.head(2)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
# To Present species of Clients ::
speciess = df["species"].value_counts()
speciess
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# Visualize Comparing aMonge Male and Female ::
sns.set( rc = {"figure.figsize" : [20 ,20]} , font_scale=1.5)
speciess.plot.pie(autopct = "%1.0f%%" , radius = 0.8 , labeldistance = 1.2 , fontsize = 30)
plt.title("Pie Chart of species")
plt.show()

# %%
# To Present island of Clients ::
islands = df["island"].value_counts()
islands
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
islands.plot.pie(autopct = "%1.0f%%" , radius = 0.8 , labeldistance = 1.2 , fontsize = 30)
plt.title("Pie Chart of island")
# Out:
# Text(0.5, 1.0, 'Pie Chart of island')

# %%
# To Present sex of Clients ::
sexs = df["sex"].value_counts()
sexs
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
sexs.plot.pie(autopct = "%1.0f%%" , radius = 0.8 , labeldistance = 1.2 , fontsize = 30)
plt.title("Pie Chart of sex")
# Out:
# Text(0.5, 1.0, 'Pie Chart of sex')

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.distplot(df["culmen_length_mm"] , kde=False , color="r")
plt.title("Distribution Plot of culmen_length_mm")
# Out:
# Text(0.5, 1.0, 'Distribution Plot of culmen_length_mm')

# %%
sns.kdeplot(df["culmen_length_mm"] , shade=True , color="r")
plt.title("Kde Plot of culmen_length_mm")
# Out:
# Text(0.5, 1.0, 'Kde Plot of culmen_length_mm')

# %%
sns.distplot(df["culmen_depth_mm"] , kde=False , color="r")
plt.title("Distribution Plot of culmen_depth_mm")
# Out:
# Text(0.5, 1.0, 'Distribution Plot of culmen_depth_mm')

# %%
sns.kdeplot(df["culmen_depth_mm"] , shade=True , color="r")
plt.title("Kde Plot of culmen_depth_mm")
# Out:
# Text(0.5, 1.0, 'Kde Plot of culmen_depth_mm')

# %%
sns.distplot(df["flipper_length_mm"] , kde=False , color="r")
plt.title("Distribution Plot of flipper_length_mm")
# Out:
# Text(0.5, 1.0, 'Distribution Plot of flipper_length_mm')

# %%
sns.kdeplot(df["flipper_length_mm"] , shade=True , color="r")
plt.title("Kde Plot of flipper_length_mm")
# Out:
# Text(0.5, 1.0, 'Kde Plot of flipper_length_mm')

# %%
sns.distplot(df["body_mass_g"] , kde=False , color="r")
plt.title("Distribution Plot of body_mass_g")
# Out:
# Text(0.5, 1.0, 'Distribution Plot of body_mass_g')

# %%
sns.kdeplot(df["body_mass_g"] , shade=True , color="r")
plt.title("Kde Plot of body_mass_g")
# Out:
# Text(0.5, 1.0, 'Kde Plot of body_mass_g')

# %%
sns.set( rc = {"figure.figsize" : [30 , 30]} , font_scale=1.2)
sns.pairplot(df , hue = "sex")

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.set( rc = {"figure.figsize" : [20 , 20]} , font_scale=1.7)
sns.swarmplot( x = "species" , y = "culmen_length_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of species and culmen_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of species and culmen_length_mm Based on sex ')

# %%
sns.swarmplot( x = "species" , y = "culmen_depth_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of species and culmen_depth_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of species and culmen_depth_mm Based on sex ')

# %%
sns.swarmplot( x = "species" , y = "flipper_length_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of species and flipper_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of species and flipper_length_mm Based on sex ')

# %%
sns.swarmplot( x = "species" , y = "body_mass_g" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of species and body_mass_g Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of species and body_mass_g Based on sex ')

# %%
sns.swarmplot( x = "island" , y = "culmen_length_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of island and culmen_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of island and culmen_length_mm Based on sex ')

# %%
sns.swarmplot( x = "island" , y = "culmen_depth_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of island and culmen_depth_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of island and culmen_depth_mm Based on sex ')

# %%
sns.swarmplot( x = "island" , y = "flipper_length_mm" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of island and flipper_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of island and flipper_length_mm Based on sex ')

# %%
sns.swarmplot( x = "island" , y = "body_mass_g" , data = df ,hue = "sex" ,  palette="Dark2" , dodge=True)
plt.title("Swarm Plot of island and body_mass_g Based on sex ")
# Out:
# Text(0.5, 1.0, 'Swarm Plot of island and body_mass_g Based on sex ')

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.boxplot( x = "species" , y = "culmen_length_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of species and culmen_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of species and culmen_length_mm Based on sex ')

# %%
sns.boxplot( x = "species" , y = "culmen_depth_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of species and culmen_depth_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of species and culmen_depth_mm Based on sex ')

# %%
sns.boxplot( x = "species" , y = "flipper_length_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of species and flipper_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of species and flipper_length_mm Based on sex ')

# %%
sns.boxplot( x = "species" , y = "body_mass_g" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of species and body_mass_g Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of species and body_mass_g Based on sex ')

# %%
sns.boxplot( x = "island" , y = "culmen_length_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of island and culmen_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of island and culmen_length_mm Based on sex ')

# %%
sns.boxplot( x = "island" , y = "culmen_depth_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of island and culmen_depth_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of island and culmen_depth_mm Based on sex ')

# %%
sns.boxplot( x = "island" , y = "flipper_length_mm" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of island and flipper_length_mm Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of island and flipper_length_mm Based on sex ')

# %%
sns.boxplot( x = "island" , y = "body_mass_g" , data = df ,hue = "sex" ,  palette="viridis" , dodge=True)
plt.title("Box Plot of island and body_mass_g Based on sex ")
# Out:
# Text(0.5, 1.0, 'Box Plot of island and body_mass_g Based on sex ')

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.countplot( x = "island"  , data = df ,hue="sex" , palette="Dark2")
plt.title("Count Plot of island  Based on sex ")
# Out:
# Text(0.5, 1.0, 'Count Plot of island  Based on sex ')

# %%
sns.countplot( x = "species"  , data = df ,hue="sex" , palette="Dark2")
plt.title("Count Plot of species  Based on sex ")
# Out:
# Text(0.5, 1.0, 'Count Plot of species  Based on sex ')

# %%
sns.countplot( x = "species"  , data = df  , palette="viridis" )
plt.title("The Count of species")
# Out:
# Text(0.5, 1.0, 'The Count of species')

# %%
sns.countplot( x = "island"  , data = df  , palette="viridis" )
plt.title("The Count of island")
# Out:
# Text(0.5, 1.0, 'The Count of island')

# %%
sns.countplot( x = "sex"  , data = df  , palette="viridis" )
plt.title("The Count of sex")
# Out:
# Text(0.5, 1.0, 'The Count of sex')

# %%
sns.set( rc = {"figure.figsize" : [10 , 10]} , font_scale=1.2)

sns.scatterplot(data = df , y = 'culmen_length_mm'  , x = 'culmen_depth_mm' , hue = 'species')
# Out:
# <AxesSubplot:xlabel='culmen_depth_mm', ylabel='culmen_length_mm'>

# %%
sns.scatterplot(data = df , x = 'culmen_depth_mm' , y = 'flipper_length_mm', hue = 'species')
# Out:
# <AxesSubplot:xlabel='culmen_depth_mm', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data = df , x = 'culmen_depth_mm'  , y = 'body_mass_g' , hue = 'species')
# Out:
# <AxesSubplot:xlabel='culmen_depth_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data = df , x ='culmen_length_mm'  , y ='body_mass_g' , hue = 'species')
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data = df , x ='flipper_length_mm' ,  y='body_mass_g' ,  hue = 'species')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data = df , x ='culmen_length_mm'  ,  y ='flipper_length_mm' ,  hue = 'species')
plt.show()

# %%
# get describtion file of data ::

profile = pp.ProfileReport(df , title = "Penguin_Report" , explorative=True)
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# To save report as html file
profile.to_file("Penguin_Data_Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# <p id = "ETl">ETL-Process</p>

# %% [markdown]
# # 1 - Feature_Engineering Technice ::
# *********************************************************************
# * Its one of the most important phase in data scientist life cycle which use to generate new usefull features from the old  features which not enough for train model.

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # 2 - Transform_data ::
# *************************************************
# * 2 :: *Cleancing data* ::
#      * Data in the real state dont comes cleaned is come dirty may include ::
#          * non_logic_data_values.
#          * Noisy and Errors.
#          * Duplicaties data.
#          * Missing_data_Values.

# %% [markdown]
# # non_logic_Values ::
# ***********************************
# * Its one of the common issuse which consider us on data which data may include errors , noisy data such as :
#     * Negaive values and that not logic.
#     * Fraction Values and that not logic also.

# %%
# Check data include Non_logic data_Values ::

for col in df.columns :
    print(f"The Col ({col})\n")
    print(f"The Unique Values of ({col}) :: {df[col].unique()}\n\n")
    print(f"The Value_Counts of ({col}) :: \n{df[col].value_counts()}")
    print("-" * 80)
# Out:
# The Col (species)
#
# The Unique Values of (species) :: ['Adelie' 'Chinstrap' 'Gentoo']
#
#
# The Value_Counts of (species) ::
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64
# --------------------------------------------------------------------------------
# The Col (island)
#
# The Unique Values of (island) :: ['Torgersen' 'Biscoe' 'Dream']
#
#
# The Value_Counts of (island) ::
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64
# --------------------------------------------------------------------------------
# The Col (culmen_length_mm)
#
# The Unique Values of (culmen_length_mm) :: [39.1 39.5 40.3  nan 36.7 39.3 38.9 39.2 34.1 42.  37.8 41.1 38.6 34.6
#  36.6 38.7 42.5 34.4 46.  37.7 35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2
#  40.9 36.4 42.2 37.6 39.8 36.5 40.8 36.  44.1 37.  39.6 37.5 42.3 40.1
#  35.  34.5 41.4 39.  35.7 41.3 41.6 35.5 41.8 33.5 39.7 45.8 42.8 36.2
# ...

# %%
df[df['sex']=='.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df.loc[336,'sex'] = 'FEMALE'

# %%
df[df['sex']=='.']
# Out:
# Empty DataFrame
# Columns: [species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %% [markdown]
# # Dublicates data ::
# ***************************
# * Its also one of the most common issue which may found reapat or redendant data that generate from :
#     * Miss understanding from data entry person.
#     * There are two cols have diff names but present the same entity.

# %%
# detect duplicated data ::

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * FromThe result above we not find duplicated data .

# %%
# To confirm that ::
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Missing Dtat Values ::
# **********************************
# * Its The Most common issue which consider us on data that generate from ::
#     * Miss understanding from data entry person.
#     * Falier the impute system.
# * We must identify that missing data and impute it, we will solve that issue by ::
#     * Fill Missing values use :
#         * Mean value if data not include outliers.
#         * Median value if data include outliers.
#         * Mode value if that categorical data.
#     * Or Impute data use :;
#         * Simpleimputer ML Technice.
#         * KNN ML Model.

# %%
# detect missing data values ::

df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
Num_Missing     = df.isnull().sum().sort_values(ascending = False)
Precent_Missing = ( df.isnull().sum() / df.isnull().count() ).sort_values(ascending = False)
Missing_Data    = pd.concat( [ Num_Missing , Precent_Missing ] ,axis=1 , keys = ["Num_Missing" , "Prec_Missing"])
Missing_Data
# Out:
#                    Num_Missing  Prec_Missing
# sex                         10      0.029070
# culmen_length_mm             2      0.005814
# culmen_depth_mm              2      0.005814
# flipper_length_mm            2      0.005814
# body_mass_g                  2      0.005814
# species                      0      0.000000
# island                       0      0.000000

# %%
Numirical_feats = df.select_dtypes(include=["number"]).columns
Numirical_feats
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g'],
#       dtype='object')

# %%
# Fill null values in Numerical feats using mean
for col in Numirical_feats :
    df[col].fillna(df[col].mean() , inplace=True)

# %%
# Fill null values in categorical feats using mode
df["sex"].fillna(df["sex"].mode()[0] , inplace=True)

# %%
# investigate data not include Missing data

Num_Missing     = df.isnull().sum().sort_values(ascending = False)
Precent_Missing = ( df.isnull().sum() / df.isnull().count() ).sort_values(ascending = False)
Missing_Data    = pd.concat( [ Num_Missing , Precent_Missing ] ,axis=1 , keys = ["Num_Missing" , "Prec_Missing"])
Missing_Data
# Out:
#                    Num_Missing  Prec_Missing
# species                      0           0.0
# island                       0           0.0
# culmen_length_mm             0           0.0
# culmen_depth_mm              0           0.0
# flipper_length_mm            0           0.0
# body_mass_g                  0           0.0
# sex                          0           0.0

# %% [markdown]
# * 3 :: *Data_Preprocessing* ::
#     * Data may include ::
#         * Outliers values.
#         * Impalanced classes.
#         * Text data.

# %% [markdown]
# # Outliers Values ::
# **********************************
# * Its one of the most common issuse which conseder us on data But we must investigate that value already outliers or anominal data values Based on ::
#     * Understanding the domain of the Business well.
#     * If num of ouliers values few that mean may that values outlier.
#     * If num of outliers values hue that mean may that values not outliers.
# * If that data outlier we will replace it by mean value or drop it.

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# detect outliers values in culmen_length_mm feature ::

sns.boxplot  (y = "culmen_length_mm" , data = df , palette="viridis")
sns.stripplot(y = "culmen_length_mm" , data = df , color = "r")
# Out:
# <AxesSubplot:ylabel='culmen_length_mm'>

# %%
# detect outliers values in culmen_depth_mm feature ::

sns.boxplot  (y = "culmen_depth_mm" , data = df , palette="viridis")
sns.stripplot(y = "culmen_depth_mm" , data = df , color = "r")
# Out:
# <AxesSubplot:ylabel='culmen_depth_mm'>

# %%
# detect outliers values in flipper_length_mm feature ::

sns.boxplot  (y = "flipper_length_mm" , data = df , palette="viridis")
sns.stripplot(y = "flipper_length_mm" , data = df , color = "r")
# Out:
# <AxesSubplot:ylabel='flipper_length_mm'>

# %%
# detect outliers values in body_mass_g feature ::

sns.boxplot  (y = "body_mass_g" , data = df , palette="viridis")
sns.stripplot(y = "body_mass_g" , data = df , color = "r")
# Out:
# <AxesSubplot:ylabel='body_mass_g'>

# %% [markdown]
# * From the result above we can see that the MonthlyCharges feature not include outliers values.

# %% [markdown]
# # Processing Text data ::
# **********************************************
# * We must handling test data into numerical numbers becouse ML Models not understanding that text data so that we use one_hot_encoding or one_variable_encoding technices.

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
# Target variable can also be encoded using sklearn.preprocessing.LabelEncoder
df['species']=df['species'].map({'Adelie':0,'Gentoo':1,'Chinstrap':2})

#Convertin the predictor variable in a binary numeric variable
df['sex'].replace(to_replace='MALE', value=1, inplace=True)
df['sex'].replace(to_replace='FEMALE',  value=0, inplace=True)

# %%
# creating dummy variables for categorical features
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#      species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0          39.10000         18.70000         181.000000
# 1          0          39.50000         17.40000         186.000000
# 2          0          40.30000         18.00000         195.000000
# 3          0          43.92193         17.15117         200.915205
# 4          0          36.70000         19.30000         193.000000
# ..       ...               ...              ...                ...
# 339        1          43.92193         17.15117         200.915205
# 340        1          46.80000         14.30000         215.000000
# 341        1          50.40000         15.70000         222.000000
# 342        1          45.20000         14.80000         212.000000
# 343        1          49.90000         16.10000         213.000000
#
#      body_mass_g  sex  island_Dream  island_Torgersen
# 0    3750.000000    1             0                 1
# ...

# %%
# get correlation between all features ::
sns.set( rc = {"figure.figsize" : [20 , 20]} , font_scale=1.5)
corr = df.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=.2, cmap="YlGnBu", annot=True , linecolor="b")

# %%
# Get Correlation of "Churn" with other features ::
sns.set( rc = {"figure.figsize" : [10 , 10]} , font_scale=1.5)

plt.figure(figsize=(15,8))
df.corr()['sex'].sort_values(ascending = False).plot(kind='bar'  )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3 :: Feture selection ::
# ***************************************************
# * There are multi technices to get the most Correlation Columns with our target.

# %% [markdown]
# <p id = "Prepration">Data-Prepration</p>

# %%
# Split data into input and output data
x = df.drop("sex" , axis=1 )
y = df["sex"]

# %%
# Spliting data into Training and Testing data ::
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split( x , y , random_state = 20 , test_size=0.2)

# %%
 #Scalling data ::
from sklearn.preprocessing import StandardScaler
scaller = StandardScaler()
x_train = scaller.fit_transform(x_train)
x_test  = scaller.transform(x_test)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    int64
#  1   culmen_length_mm   344 non-null    float64
#  2   culmen_depth_mm    344 non-null    float64
#  3   flipper_length_mm  344 non-null    float64
#  4   body_mass_g        344 non-null    float64
#  5   sex                344 non-null    int64
#  6   island_Dream       344 non-null    uint8
#  7   island_Torgersen   344 non-null    uint8
# dtypes: float64(4), int64(2), uint8(2)
# memory usage: 19.5 KB

# %% [markdown]
# <p id = "Model">Bulid_ML_Model</p>

# %% [markdown]
# # Build Models ::
# *************************************
# * On that Process we will ::
#     * Bulid multi models fror classification problem.
#     * Evaluate all models.
#     * Select the most efficient model for churn problem.

# %%
# Import All Classification Algos ::
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB , MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score , confusion_matrix 
from sklearn.metrics import classification_report , f1_score , precision_recall_curve

# %%
Models = {"Log_Classifer" : LogisticRegression() ,
          "DT_Classifer"  : DecisionTreeClassifier() ,
          "RF_Classifer"  : RandomForestClassifier() ,
          "XGB_Classifer" : XGBClassifier() ,
          "SVC_Classifer" : SVC(),
          "GassianNB_Classifiier" : GaussianNB() ,
          "KNN_Classifier" : KNeighborsClassifier()
         }

# %%
for Name , Model in Models.items() :
    print(f"The Model :: {Name}\n----------")
    Model.fit(x_train , y_train)
    Train_score = Model.score(x_train , y_train)
    Test_score  = Model.score(x_test , y_test)
    y_pred = Model.predict(x_test)
    Acurace_Score = accuracy_score(y_test , y_pred)
    Con_Matrix = confusion_matrix(y_test , y_pred)
    print(f"The Traing_Score :: {Train_score}\nThe Testing_Score :: {Test_score}\nThe Accuracy_Scor :: {Acurace_Score}\nThe Con_Matrix ::\n {Con_Matrix}\n=================\n=================")
# Out:
# The Model :: Log_Classifer
# ----------
# The Traing_Score :: 0.8836363636363637
# The Testing_Score :: 0.927536231884058
# The Accuracy_Scor :: 0.927536231884058
# The Con_Matrix ::
#  [[27  3]
#  [ 2 37]]
# ...
# The Model :: DT_Classifer
# ----------
# The Traing_Score :: 1.0
# The Testing_Score :: 0.8260869565217391
# The Accuracy_Scor :: 0.8260869565217391
# The Con_Matrix ::
#  [[24  6]
#  [ 6 33]]
# ...
# The Model :: RF_Classifer
# ----------
# The Traing_Score :: 1.0
# The Testing_Score :: 0.9130434782608695
# The Accuracy_Scor :: 0.9130434782608695
# The Con_Matrix ::
#  [[27  3]
#  [ 3 36]]
# ...
# The Model :: XGB_Classifer
# ----------
# [06:05:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The Traing_Score :: 1.0
# ...

# %% [markdown]
# * Select most efficient model with high Performance and accuracy

# %%
RF_Model = RandomForestClassifier(criterion="entropy" , random_state =20 ,oob_score = True, n_estimators=1000 , max_depth=100, n_jobs=-1 )
RF_Model.fit(x_train , y_train)
print(RF_Model.score(x_train , y_train))
print(RF_Model.score(x_test , y_test))
print("-" * 80)
# Out:
# 1.0
# 0.8840579710144928
# --------------------------------------------------------------------------------

# %% [markdown]
# <p id = "Evaluation">Evaluate_Model</p>

# %% [markdown]
# # Evaluate Model ::
# *********************************
# * Its one off the most important phase in data scientist life cycle which estimate the performance and accuracy of the model in that problem.

# %%
RF_Model.score(x_train , y_train)
# Out:
# 1.0

# %%
RF_Model.score(x_test , y_test)
# Out:
# 0.8840579710144928

# %%
Ac_Sore_RF = accuracy_score(y_test , y_pred)
Ac_Sore_RF
# Out:
# 0.8840579710144928

# %%
con_Matrix = confusion_matrix(y_test , y_pred)
con_Matrix
# Out:
# array([[27,  3],
#        [ 5, 34]], dtype=int64)

# %%
sns.set( rc = {"figure.figsize" : [10 , 10]} , font_scale=1.5)

sns.heatmap(con_Matrix , annot = True , cmap="RdYlBu" , linecolor = 'k' , linewidths= 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <p id = "Save">Save_Model</p>

# %% [markdown]
# # Save techinces ::
# ***************************************
# * Save Scaler
# * Save PCA
# * Save Model

# %%
import joblib

# %%
scaler = joblib.dump(scaller , "scaler.h5")

# %%
Model = joblib.dump(RF_Model , "Model.h5")

# %% [markdown]
# <p id = "conclusions">conclusions</p>

# %% [markdown]
# # Conclusion ::
# *****************************
# * On that Step We will ::
#   * Input data features.
#   * Scaling input data.
#   * Predict sex label.

# %%
df.head(2)
# Out:
#    species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0        0              39.1             18.7              181.0       3750.0
# 1        0              39.5             17.4              186.0       3800.0
#
#    sex  island_Dream  island_Torgersen
# 0    1             0                 1
# 1    0             0                 1

# %%
x.columns
# Out:
# Index(['species', 'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen'],
#       dtype='object')

# %%
custom_data = np.array([1 , 34.8 , 15.8 , 180.0 , 3750.0 , 0 , 1])

# %%
custom_data.shape
# Out:
# (7,)

# %%
custom_data = scaller.transform([custom_data])
custom_data
# Out:
# array([[ 0.34416291, -1.6516989 , -0.68067462, -1.45852137, -0.53917371,
#         -0.77986354,  2.42383993]])

# %%
prediction = RF_Model.predict(custom_data)
prediction
# Out:
# array([0], dtype=int64)

# %%
custom_data2 = np.array([0 , 39.1 , 18.7 , 181.0 , 3750.0 , 0 , 1])

# %%
custom_data2 = scaller.transform([custom_data2])
custom_data2
# Out:
# array([[-0.97034821, -0.85701318,  0.82052698, -1.38670301, -0.53917371,
#         -0.77986354,  2.42383993]])

# %%
prediction = RF_Model.predict(custom_data2)
prediction
# Out:
# array([1], dtype=int64)
