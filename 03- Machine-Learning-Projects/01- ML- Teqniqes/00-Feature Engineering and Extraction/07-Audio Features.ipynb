# %% [markdown]
# # Audio Features
# ## Mel Frequency Cepstral Coefficients (MFCCs)
# The mel frequency cepstral coefficients (MFCCs) of a signal are a small set of features (usually about 10-20) which concisely describe the overall shape of a spectral envelope. In MIR, it is often used to describe timbre.
# <img src='https://miro.medium.com/max/1400/1*dWnjn5LLS0j8St53ACwqSg.jpeg'/>

# %%
pip install --user librosa
# Out:
# ...
#   Using cached librosa-0.8.0-py3-none-any.whl
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import matplotlib.pyplot as plt
import IPython.display
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import librosa
import librosa.display as ds
# vector of signal   ,, fs = sample_rate
x, fs = librosa.load('../dastasets/drum.wav')
ds.waveplot(x, sr=fs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2de2f7346c53> in <module>
# ----> 1 import librosa
#       2 import librosa.display as ds
#       3 # vector of signal   ,, fs = sample_rate
#       4 x, fs = librosa.load('../dastasets/drum.wav')
#       5 ds.waveplot(x, sr=fs)
#
# ModuleNotFoundError: No module named 'librosa'

# %%
IPython.display.Audio(x, rate=fs)

# %%
# num of samples
len(x)
# Out:
# 66150

# %%
x
# Out:
# array([-0.00662231, -0.00314331,  0.00375366, ...,  0.        ,
#         0.        ,  0.        ], dtype=float32)

# %%
# num of sample in minute
fs
# Out:
# 22050

# %%
len(x) / fs
# Out:
# 3.0

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)
mfccs.shape
# Out:
# (20, 130)

# %% [markdown]
# ### Another example

# %%
x, fs = librosa.load('../dastasets/piano.wav')
ds.waveplot(x, sr=fs)

# %%
IPython.display.Audio(x, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs
# Out:
# 22050

# %%
x
# Out:
# array([-2.1797222e-04, -2.0002610e-04, -2.3527301e-04, ...,
#         1.4716045e-04,  7.6491444e-05,  0.0000000e+00], dtype=float32)

# %%
len(x)
# Out:
# 139059

# %%
len(x) / fs
# Out:
# 6.306530612244898

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)
mfccs.shape
# Out:
# (20, 272)

# %%
mfccs
# Out:
# array([[-1.90634277e+02, -2.21690552e+02, -2.99636719e+02, ...,
#         -5.03670105e+02, -5.03670105e+02, -5.03670105e+02],
#        [ 1.21722626e+02,  1.28618027e+02,  1.45643311e+02, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.91876564e+01,  2.20142136e+01,  3.69292221e+01, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 1.17276306e+01,  1.14679070e+01,  5.40189219e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-9.10788774e-02,  4.70471954e+00,  3.46672106e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-5.01659870e+00, -2.76751852e+00,  2.52230644e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]], dtype=float32)

# %%
mfccs.reshape(2600)
# Out:
# array([-190.63428, -221.69055, -299.63672, ...,    0.     ,    0.     ,
#           0.     ], dtype=float32)

# %% [markdown]
# # Great Work!
